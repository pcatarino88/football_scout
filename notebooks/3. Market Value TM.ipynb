# %% [markdown]
# # Setup

# %% [markdown]
# 📝 *Import required libraries and files:*

# %%
import pandas as pd
import numpy as np

#    ---- Scrape Market Value ----
import requests, time, random, re
from bs4 import BeautifulSoup
import os, time, random, re
from pathlib import Path

# %%
path = "dfs/df_proc.parquet"
df_proc = pd.read_parquet(path)
pd.set_option('display.max_columns', None)
print(f"Shape of df: {df_proc.shape}")
df_proc.head(2)
# Out:
# Shape of df: (8367, 166)
#    PlayerID         Player League             Squad  elegible  Position Pos  \
# 0         1  Matías Abaldo   arg1     Independiente         0   Forward  FW
# 1         2  Lucas Abascia   arg1  Cen. Córdoba–SdE         1  Defender  DF
#
#    Age Nation  Matches  Starts  Minutes  Goals  Expected Goals  \
# 0   21    URU        3       3      201      0             0.2
# 1   30    ARG       14      11     1063      1             0.8
#
#    Goals Minus Expected  Goals not Penalty  Penalty Goals  Penalty Efficacy  \
# 0                  -0.2                  0              0               NaN
# 1                   0.2                  1              0               NaN
#
#    Shoots  Shoots on Target  Goals/Shoot  AvgShoot Distance  FreeKick Tacker  \
# 0       2                 1         0.00               16.7                0
# 1       9                 2         0.11               17.2                0
#
#    Assists  Crosses  Penalty Won  Offsides  Cmp Passes  Cmp Passes%  \
# 0        0        3            0         3          45         70.3
# 1        1        0            0         0         542         79.5
#
#    Prog Passes  Passing Distance  Pass Prog Distance  Short Cmp  Short Cmp%  \
# 0            8               597                 231         29        80.6
# 1           46             11663                4182        149        86.6
#
#    Medium Cmp  Medium Cmp%  Long Cmp  Long Cmp%  Key Passes  \
# 0          13         72.2         2       50.0           1
# 1         305         89.7        85       53.8           2
#
#    Goal Creating Actions  Take-Ons Succ  Take-Ons Succ%  Fouls Suffered  \
# 0                      4              1            12.5               3
# 1                     12              4            57.1              11
#
#    Carries  Carries TotDist  Prog Carries  Carries PrgDist  Carries 1/3  \
# 0       50              226             3               82            0
# 1      448             2377             7             1442            5
#
#    Touches  Errors  Aerial Duels  Aerial Duels Won%  Tackles  Tackles Won  \
# 0       96       0             6               50.0        2            1
# 1      880       1            64               50.0       26           17
#
#    Blocks  Interceptions  Ball Recoveries  Clearances  Own Goals  \
# 0       3              1                7           0          0
# 1      16             36               70          93          0
#
#    Fouls Commited  Penalty Commited  Yellow Cards  Red Cards  Goals_90m  \
# 0               0                 0             0          0      0.000
# 1               6                 0             2          0      0.085
#
#    Expected Goals_90m  Goals Minus Expected_90m  Goals not Penalty_90m  \
# 0               0.090                    -0.090                  0.000
# 1               0.068                     0.017                  0.085
#
#    Penalty Goals_90m  Shoots_90m  Shoots on Target_90m  Assists_90m  \
# 0                0.0       0.896                 0.448        0.000
# 1                0.0       0.762                 0.169        0.085
#
#    Crosses_90m  Penalty Won_90m  Offsides_90m  Cmp Passes_90m  \
# 0        1.343              0.0         1.343          20.149
# 1        0.000              0.0         0.000          45.889
#
#    Prog Passes_90m  Passing Distance_90m  Pass Prog Distance_90m  \
# 0            3.582               267.313                 103.433
# 1            3.895               987.460                 354.073
#
#    Short Cmp_90m  Medium Cmp_90m  Long Cmp_90m  Key Passes_90m  \
# 0         12.985           5.821         0.896           0.448
# 1         12.615          25.823         7.197           0.169
#
#    Goal Creating Actions_90m  Take-Ons Succ_90m  Fouls Suffered_90m  \
# 0                      1.791              0.448               1.343
# 1                      1.016              0.339               0.931
#
#    Carries_90m  Carries TotDist_90m  Prog Carries_90m  Carries PrgDist_90m  \
# 0       22.388              101.194             1.343               36.716
# 1       37.930              201.251             0.593              122.088
#
#    Carries 1/3_90m  Touches_90m  Errors_90m  Aerial Duels_90m  Tackles_90m  \
# 0            0.000       42.985       0.000             2.687        0.896
# 1            0.423       74.506       0.085             5.419        2.201
#
#    Tackles Won_90m  Blocks_90m  Interceptions_90m  Ball Recoveries_90m  \
# 0            0.448       1.343              0.448                3.134
# 1            1.439       1.355              3.048                5.927
#
#    Clearances_90m  Own Goals_90m  Fouls Commited_90m  Penalty Commited_90m  \
# 0           0.000            0.0               0.000                   0.0
# 1           7.874            0.0               0.508                   0.0
#
#    Yellow Cards_90m  Red Cards_90m  Goals_90m_scaled  \
# 0             0.000            0.0               NaN
# 1             0.169            0.0             0.099
#
#    Expected Goals_90m_scaled  Goals Minus Expected_90m_scaled  \
# 0                        NaN                              NaN
# 1                      0.089                            0.529
#
#    Goals not Penalty_90m_scaled  Penalty Goals_90m_scaled  \
# 0                           NaN                       NaN
# 1                         0.105                       0.0
#
#    Penalty Efficacy_scaled  Shoots_90m_scaled  Shoots on Target_90m_scaled  \
# 0                      NaN                NaN                          NaN
# 1                      NaN              0.176                         0.09
#
#    Goals/Shoot_scaled  AvgShoot Distance_scaled  Assists_90m_scaled  \
# 0                 NaN                       NaN                 NaN
# 1                0.22                     0.431               0.162
#
#    Crosses_90m_scaled  Penalty Won_90m_scaled  Offsides_90m_scaled  \
# 0                 NaN                     NaN                  NaN
# 1                 0.0                     0.0                  0.0
#
#    Cmp Passes_90m_scaled  Cmp Passes%_scaled  Prog Passes_90m_scaled  \
# 0                    NaN                 NaN                     NaN
# 1                  0.527               0.667                   0.361
#
#    Passing Distance_90m_scaled  Pass Prog Distance_90m_scaled  \
# 0                          NaN                            NaN
# 1                         0.65                          0.675
#
#    Short Cmp_90m_scaled  Short Cmp%_scaled  Medium Cmp_90m_scaled  \
# 0                   NaN                NaN                    NaN
# 1                 0.245              0.724                  0.587
#
#    Medium Cmp%_scaled  Long Cmp_90m_scaled  Long Cmp%_scaled  \
# 0                 NaN                  NaN               NaN
# 1               0.848                0.745             0.476
#
#    Key Passes_90m_scaled  Goal Creating Actions_90m_scaled  \
# 0                    NaN                               NaN
# 1                  0.053                              0.13
#
#    Take-Ons Succ_90m_scaled  Take-Ons Succ%_scaled  Fouls Suffered_90m_scaled  \
# 0                       NaN                    NaN                        NaN
# 1                     0.101                  0.571                      0.235
#
#    Carries_90m_scaled  Carries TotDist_90m_scaled  Prog Carries_90m_scaled  \
# 0                 NaN                         NaN                      NaN
# 1               0.529                       0.513                    0.091
#
#    Carries PrgDist_90m_scaled  Carries 1/3_90m_scaled  Touches_90m_scaled  \
# 0                         NaN                     NaN                 NaN
# 1                       0.605                   0.109               0.694
#
#    Errors_90m_scaled  Aerial Duels_90m_scaled  Aerial Duels Won%_scaled  \
# 0                NaN                      NaN                       NaN
# 1              0.262                    0.447                     0.585
#
#    Tackles_90m_scaled  Tackles Won_90m_scaled  Blocks_90m_scaled  \
# 0                 NaN                     NaN                NaN
# 1               0.488                   0.509              0.532
#
#    Interceptions_90m_scaled  Ball Recoveries_90m_scaled  \
# 0                       NaN                         NaN
# 1                       1.0                        0.72
#
#    Clearances_90m_scaled  Own Goals_90m_scaled  Fouls Commited_90m_scaled  \
# 0                    NaN                   NaN                        NaN
# 1                  0.905                   0.0                      0.102
#
#    Penalty Commited_90m_scaled  Yellow Cards_90m_scaled  Red Cards_90m_scaled  \
# 0                          NaN                      NaN                   NaN
# 1                          0.0                    0.199                   0.0
#
#    Goal Scoring  Goal Efficacy  Shooting  Passing Influence  Passing Accuracy  \
# 0           NaN            NaN       NaN                NaN               NaN
# 1         0.101            0.3     0.111              0.487             0.674
#
#    Goal Creation  Possession Influence  Progression  Dribling  \
# 0            NaN                   NaN          NaN       NaN
# 1          0.107                 0.536        0.297     0.336
#
#    Aerial Influence  Defensive Influence  Discipline and Consistency
# 0               NaN                  NaN                         NaN
# 1              0.53                0.679                       0.909

# %% [markdown]
# # 3.1. - Scrape Transfermarkt: Market Value and Position

# %%
def get_market_value_and_position(player_name: str):
    """
    Query transfermarkt.co.uk quick-search and return (market_value_str, position_str)
    for the FIRST player result. Example: ("€35.00m", "RW").
    """
    base_url = "https://www.transfermarkt.co.uk/schnellsuche/ergebnis/schnellsuche"
    headers = {
        "User-Agent": (
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
            "(KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36"
        ),
        "Accept-Language": "en-GB,en;q=0.9",
        "Referer": "https://www.transfermarkt.co.uk/",
    }
    params = {"query": player_name}

    def _norm(s: str) -> str:
        return re.sub(r"\s+", " ", s).strip().lower()

    try:
        r = requests.get(base_url, headers=headers, params=params, timeout=20)
        r.raise_for_status()
        soup = BeautifulSoup(r.text, "html.parser")

        # pick the players results table by header names
        table = None
        for t in soup.select("table.items"):
            hdrs = [_norm(th.get_text(" ", strip=True)) for th in t.select("thead tr th")]
            if "position" in hdrs and ("market value" in hdrs or "marketvalue" in hdrs):
                table = t
                break
        if table is None:
            # fallback: first items table
            table = soup.select_one("table.items")
        if table is None:
            print(f"No results table found for: {player_name}")
            return None, None

        row = table.select_one("tbody > tr")
        if row is None:
            print(f"No player rows for: {player_name}")
            return None, None

        # Build header index mapping (robust to column order)
        hdrs = [_norm(th.get_text(" ", strip=True)) for th in table.select("thead tr th")]
        cells = row.select("td")

        def idx_for(name):
            try:
                return hdrs.index(name)
            except ValueError:
                return None

        pos_idx = idx_for("position")
        mv_idx  = idx_for("market value")

        # Primary extraction via header indices
        position = cells[pos_idx].get_text(" ", strip=True) if pos_idx is not None else None
        market_value = cells[mv_idx].get_text(" ", strip=True) if mv_idx is not None else None

        # Fallbacks if headers/indices fail
        if market_value in (None, ""):
            # Typical MV cell has classes 'rechts hauptlink' and contains € or £
            mv_td = row.select_one("td.rechts.hauptlink")
            market_value = mv_td.get_text(" ", strip=True) if mv_td else None
            if not market_value:
                for td in cells:
                    txt = td.get_text(" ", strip=True)
                    if "€" in txt or "£" in txt:
                        market_value = txt
                        break

        if position in (None, ""):
            # Look for a short positional code (GK/RB/LB/CB/DM/CM/AM/RW/LW/ST/CF…)
            for td in cells:
                txt = td.get_text(" ", strip=True)
                if re.fullmatch(r"[A-Z]{1,3}", txt):
                    position = txt
                    break

        # polite pause to be nice
        time.sleep(1 + random.uniform(0.2, 0.8))

        if not market_value and not position:
            print(f"Could not find fields for: {player_name}")
        return market_value, position

    except Exception as e:
        print(f"Error for {player_name}: {e}")
        return None, None

# %%
def _sleep_jitter(low=4, high=7):
    time.sleep(random.uniform(low, high))

def _safe_lookup(name, retries=3, base_wait=5):
    """
    Wraps your get_market_value_and_position with retries + backoff.
    Returns (mv, pos) or (None, None) on failure.
    """
    for attempt in range(retries):
        try:
            mv, pos = get_market_value_and_position(name)  # <-- YOUR function
            return mv, pos
        except Exception as e:
            wait = base_wait * (2 ** attempt) + random.uniform(0, 1.5)
            print(f"[WARN] {name}: {e} | retrying in {wait:.1f}s ({attempt+1}/{retries})")
            time.sleep(wait)
    return None, None

def scrape_tm_range(
    df: pd.DataFrame,
    *,
    start_id: int,
    end_id: int,
    id_col: str = "playerID",         
    name_col: str = "Player",
    eligible_col: str = "elegible",
    batch_size: int = 50,
    per_request_sleep=(4, 7),          
    sleep_between_batches: int = 60,   
    out_dir: str = "tm_exports",
    cumulative_file: str = "tm_cumulative.parquet",
    retries: int = 3,
    base_backoff: int = 5
) -> pd.DataFrame:
    """
    Scrape Position + Market Value from transfermarkt.co.uk for elegible players
    with IDs in [start_id, end_id]. Runs in batches of 50 by default and
    checkpoints to disk after each batch.

    Returns a DataFrame with columns:
        ['playerID','Player','Position','Market Value']
    """
    # --- prepare I/O
    out = Path(out_dir)
    out.mkdir(parents=True, exist_ok=True)
    cum_path = out / cumulative_file

    # --- normalize inputs / select elegible rows within ID range
    if id_col not in df.columns and "PlayerID" in df.columns:
        id_col = "PlayerID"  # be forgiving if they use 'PlayerID'

    work = df[[id_col, name_col, eligible_col]].copy()
    work[id_col] = pd.to_numeric(work[id_col], errors="coerce")
    work = work.dropna(subset=[id_col])
    work = work[(work[eligible_col] == 1) & (work[id_col].between(start_id, end_id))]
    work = work.sort_values(id_col)

    if work.empty:
        print("No elegible players in the requested range.")
        return pd.DataFrame(columns=["playerID", "Player", "Position", "Market Value"])

    # --- load cumulative progress (resume support)
    if cum_path.exists():
        cumulative = pd.read_parquet(cum_path)
        done_ids = set(pd.to_numeric(cumulative.get(id_col, cumulative.get("playerID")), errors="coerce").dropna().astype(int))
        print(f"Resuming: {len(done_ids)} players already scraped in cumulative.")
    else:
        cumulative = pd.DataFrame(columns=[id_col, name_col, "Position", "Market Value"])
        done_ids = set()

    # --- compute pending IDs
    ids = work[id_col].astype(int).tolist()
    names = work.set_index(id_col)[name_col].to_dict()
    pending_ids = [pid for pid in ids if pid not in done_ids]
    total_pending = len(pending_ids)
    print(f"To process now: {total_pending} elegible players "
          f"({start_id}–{end_id}, batch={batch_size}).")

    # --- main loop over batches of 50
    low, high = per_request_sleep
    for b_start in range(0, total_pending, batch_size):
        b_ids = pending_ids[b_start:b_start + batch_size]
        if not b_ids:
            break

        bmin, bmax = min(b_ids), max(b_ids)
        batch_fname = out / f"tm_{bmin:05d}_{bmax:05d}.parquet"

        # If the exact batch file already exists, merge it into cumulative and skip scraping
        if batch_fname.exists():
            print(f"Batch {bmin}-{bmax} already exists → merging into cumulative and skipping scrape.")
            try:
                existing = pd.read_parquet(batch_fname)
                cumulative = (
                    pd.concat([cumulative, existing], ignore_index=True)
                      .drop_duplicates(subset=[id_col], keep="last")
                )
                cumulative.to_parquet(cum_path, index=False)
            except Exception as e:
                print(f"[WARN] Could not read existing batch file {batch_fname.name}: {e}")
            time.sleep(sleep_between_batches)
            continue

        print(f"Batch {bmin}-{bmax} | {len(b_ids)} players")
        records = []

        for pid in b_ids:
            name = names.get(pid)
            if not name:
                continue

            # Skip if already have a non-null MV recorded for this ID
            if pid in done_ids:
                continue

            mv, pos = _safe_lookup(name, retries=retries, base_wait=base_backoff)
            records.append({id_col: pid, name_col: name, "Position": pos, "Market Value": mv})

            _sleep_jitter(low, high)  # polite pacing

        # Save batch immediately
        batch_df = pd.DataFrame(records)
        if not batch_df.empty:
            batch_df.to_parquet(batch_fname, index=False)

            # Update cumulative and save
            cumulative = (
                pd.concat([cumulative, batch_df], ignore_index=True)
                  .drop_duplicates(subset=[id_col], keep="last")
            )
            cumulative.to_parquet(cum_path, index=False)

        print(f"Saved {batch_fname.name} and updated {cum_path.name}.")
        print(f"Sleeping {sleep_between_batches}s before next batch…")
        time.sleep(sleep_between_batches)

    print("All requested batches complete.")

    # --- Final return: ensure required column names/order and rename id to 'playerID'
    out_df = cumulative[[id_col, name_col, "Position", "Market Value"]].copy()
    out_df = out_df.rename(columns={id_col: "playerID"})
    out_df = out_df.sort_values("playerID").reset_index(drop=True)

    # Return only rows in the requested range & elegible
    out_df = out_df[out_df["playerID"].between(start_id, end_id)]
    out_df = out_df.merge(
        work[[id_col]].rename(columns={id_col: "playerID"}), on="playerID", how="inner"
    )

    return out_df[["playerID", "Player", "Position", "Market Value"]]

# %% [markdown]
# Scraping in 4 batches.

# %%
result_batch1 = scrape_tm_range(
    df_scaled,
    start_id=1,
    end_id=2100,
    id_col="PlayerID",        
    name_col="Player",
    eligible_col="elegible",
    batch_size=50,
    per_request_sleep=(4, 7),
    sleep_between_batches=60,
)
# Out:
# Resuming: 100 players already scraped in cumulative.
# To process now: 1185 elegible players (1–2100, batch=50).
# Batch 166-246 | 50 players
# Saved tm_00166_00246.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 248-328 | 50 players
# No results table found for: Juan Franco Arrellaga
# Saved tm_00248_00328.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 329-409 | 50 players
# No results table found for: Pablo Galdames Millán
# No results table found for: Laurtaro Giaccone
# Could not find fields for: Jonatan Goitía
# No results table found for: Carlos González Espínola
# Saved tm_00329_00409.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 410-498 | 50 players
# Saved tm_00410_00498.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 499-576 | 50 players
# Could not find fields for: Juan Ludueña
# Saved tm_00499_00576.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 578-654 | 50 players
# Could not find fields for: Juan Meli
# Could not find fields for: Iván Morales Bravo
# Saved tm_00578_00654.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 655-733 | 50 players
# Could not find fields for: Pedro Ojeda
# No results table found for: Diego Ortegoza
# Saved tm_00655_00733.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 737-812 | 50 players
# No results table found for: Lucas Piovi
# Error for Luca Regiardo: 504 Server Error: Gateway Time-out for url: https://www.transfermarkt.co.uk/schnellsuche/ergebnis/schnellsuche?query=Luca+Regiardo
# Saved tm_00737_00812.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 813-891 | 50 players
# No results table found for: Juan Saborido
# Saved tm_00813_00891.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 892-969 | 50 players
# Saved tm_00892_00969.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 970-1051 | 50 players
# No results table found for: Christopher Bonsu-Baah
# Saved tm_00970_01051.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 1052-1135 | 50 players
# Saved tm_01052_01135.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 1137-1208 | 50 players
# No results table found for: Faisal Al Ghamdi
# Could not find fields for: Fredrik Hammer
# No results table found for: Oh Hyeon-gyu
# Saved tm_01137_01208.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 1209-1295 | 50 players
# No results table found for: Tolis Konstantopoulos
# No results table found for: Konan N'dri
# Saved tm_01209_01295.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 1296-1360 | 50 players
# Saved tm_01296_01360.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 1361-1423 | 50 players
# No results table found for: Marwan Al Sahafi
# Could not find fields for: Leonardo da Silva Lopes
# Saved tm_01361_01423.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 1425-1501 | 50 players
# Saved tm_01425_01501.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 1502-1597 | 50 players
# Could not find fields for: Leo Augusto Pereira
# No results table found for: Enmerson Batalla
# Could not find fields for: Marllon Borges
# Saved tm_01502_01597.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 1599-1675 | 50 players
# Saved tm_01599_01675.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 1677-1768 | 50 players
# No results table found for: André Filipinho
# Could not find fields for: Nuno Gonçalo Moreira
# Saved tm_01677_01768.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 1769-1866 | 50 players
# No results table found for: Jhonatan Jowjow
# Could not find fields for: Renato Kayser
# No results table found for: David Loiola
# No results table found for: Luis Mandaca
# Saved tm_01769_01866.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 1867-1956 | 50 players
# Could not find fields for: Gustavo Martins Santos
# Could not find fields for: João Pedro Pepê
# Saved tm_01867_01956.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 1957-2042 | 50 players
# Could not find fields for: Santi Ramos Mingo
# Saved tm_01957_02042.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 2043-2100 | 35 players
# Could not find fields for: Everton Soares
# Saved tm_02043_02100.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# All requested batches complete.

# %%
result_batch2 = scrape_tm_range(
    df_scaled,
    start_id=2101,
    end_id=4200,
    id_col="PlayerID",        
    name_col="Player",
    eligible_col="elegible",
    batch_size=50,
    per_request_sleep=(4, 7),
    sleep_between_batches=60,
)
# Out:
# Resuming: 1285 players already scraped in cumulative.
# To process now: 1460 elegible players (2101–4200, batch=50).
# Batch 2102-2188 | 50 players
# No results table found for: Guilherme Tinga
# Could not find fields for: Félix Torres Caicedo
# Saved tm_02102_02188.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 2189-2256 | 50 players
# No results table found for: Victor Bernth Kristiansen
# Saved tm_02189_02256.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 2257-2329 | 50 players
# Saved tm_02257_02329.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 2331-2403 | 50 players
# No results table found for: Hwang Hee-chan
# No results table found for: Son Heung-min
# Saved tm_02331_02403.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 2404-2469 | 50 players
# Saved tm_02404_02469.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 2470-2541 | 50 players
# Saved tm_02470_02541.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 2542-2618 | 50 players
# No results table found for: Nico O’Reilly
# No results table found for: Jaden Philogene Bidace
# No results table found for: Jaden Philogene Bidace
# Saved tm_02542_02618.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 2620-2687 | 50 players
# Saved tm_02620_02687.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 2689-2754 | 50 players
# Saved tm_02689_02754.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 2755-2825 | 50 players
# No results table found for: Eric Bocat
# Saved tm_02755_02825.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 2826-2889 | 50 players
# Saved tm_02826_02889.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 2890-2959 | 50 players
# Saved tm_02890_02959.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 2960-3034 | 50 players
# No results table found for: Mads Frøkjær-Jensen
# No results table found for: Tyler Goodhram
# No results table found for: Dimitris Goutas
# Saved tm_02960_03034.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 3035-3099 | 50 players
# No results table found for: Eom Jisung
# Saved tm_03035_03099.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 3100-3168 | 50 players
# No results table found for: Bae Junho
# Saved tm_03100_03168.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 3169-3235 | 50 players
# No results table found for: Yang Minhyeok
# Saved tm_03169_03235.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 3236-3308 | 50 players
# No results table found for: Jesurun Rak Sakyi
# Saved tm_03236_03308.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 3309-3383 | 50 players
# Saved tm_03309_03383.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 3384-3459 | 50 players
# Could not find fields for: Jakob Sørensen
# Saved tm_03384_03459.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 3460-3527 | 50 players
# No results table found for: Stefán Þórðarson
# Saved tm_03460_03527.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 3529-3596 | 50 players
# Saved tm_03529_03596.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 3599-3679 | 50 players
# Saved tm_03599_03679.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 3681-3751 | 50 players
# No results table found for: Pierre Højbjerg
# Saved tm_03681_03751.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 3752-3830 | 50 players
# No results table found for: Lee Kang-in
# Could not find fields for: Boubakar Kouyaté
# Saved tm_03752_03830.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 3831-3898 | 50 players
# Could not find fields for: Mohamed Meité
# No results table found for: Almoatasem Al Musrati
# Saved tm_03831_03898.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 3899-3974 | 50 players
# Saved tm_03899_03974.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 3975-4044 | 50 players
# No results table found for: Musa Al-Taamari
# No results table found for: Musa Al-Taamari
# Saved tm_03975_04044.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 4046-4121 | 50 players
# Saved tm_04046_04121.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 4122-4187 | 50 players
# Saved tm_04122_04187.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 4189-4200 | 10 players
# Saved tm_04189_04200.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# All requested batches complete.

# %%
result_batch3 = scrape_tm_range(
    df_scaled,
    start_id=4201,
    end_id=6300<,
    id_col="PlayerID",        
    name_col="Player",
    eligible_col="elegible",
    batch_size=50,
    per_request_sleep=(4, 7),
    sleep_between_batches=60,
)
# Out:
# Resuming: 2745 players already scraped in cumulative.
# To process now: 1458 elegible players (4201–6300, batch=50).
# Batch 4201-4265 | 50 players
# No results table found for: Hong Hyunseok
# No results table found for: Lee Jae-sung
# Saved tm_04201_04265.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 4266-4334 | 50 players
# No results table found for: Giorgos Masouras
# No results table found for: Jean Mattéo Bahoya
# No results table found for: Kim Min-jae
# Saved tm_04266_04334.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 4335-4410 | 50 players
# No results table found for: Joakim Mæhle
# No results table found for: Nathan N'Goumou
# No results table found for: Stanley N'Soki
# Saved tm_04335_04410.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 4411-4475 | 50 players
# Saved tm_04411_04475.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 4476-4547 | 50 players
# No results table found for: Jeong Woo-yeong
# Saved tm_04476_04547.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 4548-4625 | 50 players
# No results table found for: Jean-Daniel Akpa-Akpro
# Could not find fields for: Daniel Bandeira
# Saved tm_04548_04625.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 4627-4700 | 50 players
# Saved tm_04627_04700.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 4701-4764 | 50 players
# Saved tm_04701_04764.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 4765-4828 | 50 players
# No results table found for: Lautaro Gianetti
# No results table found for: Christian Gytkjær
# No results table found for: Þórir Jóhann Helgason
# Saved tm_04765_04828.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 4830-4894 | 50 players
# No results table found for: Marc-Oliver Kempf
# Saved tm_04830_04894.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 4896-4964 | 50 players
# No results table found for: Obite N'Dicka
# No results table found for: Konan N'dri
# Saved tm_04896_04964.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 4965-5043 | 50 players
# Saved tm_04965_05043.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 5044-5128 | 50 players
# Saved tm_05044_05128.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 5129-5193 | 50 players
# No results table found for: Milan Đurić
# Could not find fields for: Matias Antonini Lui
# Saved tm_05129_05193.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 5194-5253 | 50 players
# Saved tm_05194_05253.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 5255-5320 | 50 players
# No results table found for: Matteo Chichella
# Saved tm_05255_05320.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 5322-5394 | 50 players
# Error for Tommaso Corazza: 503 Server Error: Service Unavailable for url: https://www.transfermarkt.co.uk/schnellsuche/ergebnis/schnellsuche?query=Tommaso+Corazza
# Saved tm_05322_05394.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 5395-5470 | 50 players
# Saved tm_05395_05470.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 5471-5539 | 50 players
# Saved tm_05471_05539.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 5540-5608 | 50 players
# Could not find fields for: Simeon Nwankwo
# Saved tm_05540_05608.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 5609-5674 | 50 players
# Saved tm_05609_05674.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 5675-5749 | 50 players
# Could not find fields for: Fabio Ruggeri
# Error for Steven Shpendi: 503 Server Error: Service Unavailable for url: https://www.transfermarkt.co.uk/schnellsuche/ergebnis/schnellsuche?query=Steven+Shpendi
# Error for Giuseppe Sibilli: 503 Server Error: Service Unavailable for url: https://www.transfermarkt.co.uk/schnellsuche/ergebnis/schnellsuche?query=Giuseppe+Sibilli
# Error for Giuseppe Sibilli: 503 Server Error: Service Unavailable for url: https://www.transfermarkt.co.uk/schnellsuche/ergebnis/schnellsuche?query=Giuseppe+Sibilli
# Error for Lorenco Šimić: 503 Server Error: Service Unavailable for url: https://www.transfermarkt.co.uk/schnellsuche/ergebnis/schnellsuche?query=Lorenco+%C5%A0imi%C4%87
# Saved tm_05675_05749.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 5752-5817 | 50 players
# Could not find fields for: Freddie Veseli
# Saved tm_05752_05817.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 5818-5891 | 50 players
# Could not find fields for: Fernando Arce Jr.
# Saved tm_05818_05891.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 5892-5969 | 50 players
# No results table found for: Nicolás Díaz Huincales
# Saved tm_05892_05969.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 5970-6043 | 50 players
# Saved tm_05970_06043.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 6044-6116 | 50 players
# No results table found for: Carlos González Espínola
# No results table found for: Luis Gutiérrez Castellanos
# Saved tm_06044_06116.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 6117-6209 | 50 players
# Saved tm_06117_06209.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 6210-6282 | 50 players
# Error for Jesús Orozco: 503 Server Error: Service Unavailable for url: https://www.transfermarkt.co.uk/schnellsuche/ergebnis/schnellsuche?query=Jes%C3%BAs+Orozco
# Error for Ralph Orquin: 503 Server Error: Service Unavailable for url: https://www.transfermarkt.co.uk/schnellsuche/ergebnis/schnellsuche?query=Ralph+Orquin
# Saved tm_06210_06282.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 6283-6299 | 8 players
# Saved tm_06283_06299.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# All requested batches complete.

# %%
result_batch4 = scrape_tm_range(
    df_scaled,
    start_id=6300,
    end_id=8367,
    id_col="PlayerID",        
    name_col="Player",
    eligible_col="elegible",
    batch_size=50,
    per_request_sleep=(4, 7),
    sleep_between_batches=60,
)
# Out:
# Resuming: 4203 players already scraped in cumulative.
# To process now: 1410 elegible players (6300–8367, batch=50).
# Batch 6301-6371 | 50 players
# Saved tm_06301_06371.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 6372-6453 | 50 players
# No results table found for: Uroš Đurđević
# Error for Amar Ahmed: 503 Server Error: Service Unavailable for url: https://www.transfermarkt.co.uk/schnellsuche/ergebnis/schnellsuche?query=Amar+Ahmed
# Error for Makan Aiko: 503 Server Error: Service Unavailable for url: https://www.transfermarkt.co.uk/schnellsuche/ergebnis/schnellsuche?query=Makan+Aiko
# Error for Chuba Akpom: 503 Server Error: Service Unavailable for url: https://www.transfermarkt.co.uk/schnellsuche/ergebnis/schnellsuche?query=Chuba+Akpom
# Saved tm_06372_06453.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 6454-6529 | 50 players
# Error for Paweł Bochniewicz: 503 Server Error: Service Unavailable for url: https://www.transfermarkt.co.uk/schnellsuche/ergebnis/schnellsuche?query=Pawe%C5%82+Bochniewicz
# Error for Jeremy Bokila: 503 Server Error: Service Unavailable for url: https://www.transfermarkt.co.uk/schnellsuche/ergebnis/schnellsuche?query=Jeremy+Bokila
# Error for Ruben van Bommel: 503 Server Error: Service Unavailable for url: https://www.transfermarkt.co.uk/schnellsuche/ergebnis/schnellsuche?query=Ruben+van+Bommel
# Saved tm_06454_06529.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 6532-6606 | 50 players
# Could not find fields for: Marvin da Graça
# Saved tm_06532_06606.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 6607-6678 | 50 players
# No results table found for: Hwang In-beom
# Could not find fields for: Jochem van de Kamp
# No results table found for: Adam Kayed
# Saved tm_06607_06678.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 6679-6747 | 50 players
# No results table found for: Leftheris Lyratzis
# Saved tm_06679_06747.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 6748-6827 | 50 players
# Saved tm_06748_06827.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 6831-6901 | 50 players
# Saved tm_06831_06901.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 6903-6969 | 50 players
# No results table found for: Rúnar Þór Sigurgeirsson
# No results table found for: Shiloh ’t Zand
# Saved tm_06903_06969.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 6971-7040 | 50 players
# Could not find fields for: Fahem Benaissa Yahia
# Saved tm_06971_07040.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 7042-7108 | 50 players
# Saved tm_07042_07108.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 7109-7184 | 50 players
# Could not find fields for: Fernando Ferreira Fonseca
# Could not find fields for: Tiago Fonseca Morais
# Could not find fields for: Nuno Gonçalo Moreira
# Saved tm_07109_07184.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 7186-7262 | 50 players
# Could not find fields for: João Goulart Silva
# No results table found for: André Inácio
# No results table found for: André Inácio
# Saved tm_07186_07262.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 7263-7341 | 50 players
# No results table found for: Vitali Lystsov
# Could not find fields for: João Mário Lopes
# Saved tm_07263_07341.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 7342-7413 | 50 players
# Saved tm_07342_07413.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 7414-7489 | 50 players
# No results table found for: Matí­as Rocha
# Could not find fields for: Luís Carlos Rocha Rodrigues
# No results table found for: Guilherme Serrão
# Could not find fields for: Luís Manuel Costa Silva
# Saved tm_07414_07489.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 7493-7567 | 50 players
# No results table found for: Marcos Vinicios Sorriso
# Saved tm_07493_07567.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 7569-7636 | 50 players
# Saved tm_07569_07636.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 7637-7709 | 50 players
# Could not find fields for: Dani Carvajal
# No results table found for: Juan Cruz Armada
# Saved tm_07637_07709.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 7711-7783 | 50 players
# No results table found for: Adri Embarba
# Could not find fields for: Peter González
# Saved tm_07711_07783.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 7785-7851 | 50 players
# Could not find fields for: Juan Herzog
# Saved tm_07785_07851.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 7852-7918 | 50 players
# Error for Gerard Martín: 503 Server Error: Service Unavailable for url: https://www.transfermarkt.co.uk/schnellsuche/ergebnis/schnellsuche?query=Gerard+Mart%C3%ADn
# Error for Iván Martín: 503 Server Error: Service Unavailable for url: https://www.transfermarkt.co.uk/schnellsuche/ergebnis/schnellsuche?query=Iv%C3%A1n+Mart%C3%ADn
# No results table found for: Oliver McBurnie
# Saved tm_07852_07918.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 7920-7986 | 50 players
# Saved tm_07920_07986.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 7988-8056 | 50 players
# Could not find fields for: Yeremi Pino
# Saved tm_07988_08056.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 8057-8124 | 50 players
# Could not find fields for: Chuky san jose
# Could not find fields for: Jailson Siqueira
# Saved tm_08057_08124.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 8126-8197 | 50 players
# No results table found for: Joshua Atencio
# Saved tm_08126_08197.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 8198-8271 | 50 players
# No results table found for: Obafemi Awodesu
# No results table found for: Ramiro Benetti
# Saved tm_08198_08271.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 8272-8356 | 50 players
# No results table found for: Dagur Dan Þórhallsson
# Saved tm_08272_08356.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# Batch 8357-8367 | 10 players
# Saved tm_08357_08367.parquet and updated tm_cumulative.parquet.
# Sleeping 60s before next batch…
# All requested batches complete.

# %% [markdown]
# # 3.2. - Consolidate Data

# %%
df_tm = pd.read_parquet("tm_exports/tm_cumulative.parquet")

# %%
print(f"transfermarkt df shape: {df_tm.shape}")
df_tm.head(5)
# Out:
# transfermarkt df shape: (5613, 4)
#    PlayerID            Player Position Market Value
# 0         2     Lucas Abascia       CB        €800k
# 1         5   Ignacio Abraham       LB        €300k
# 2         6    Gonzalo Abrego       CM       €2.00m
# 3         7     Jonás Acevedo       LW       €1.00m
# 4         9  Guillermo Acosta       CM        €200k

# %%
df_final = df_proc.merge(
    df_tm[['PlayerID', 'Position', 'Market Value']],
    on='PlayerID', how='left'
)

# %%
# Drop 'Pos' column (redundant now that we have the detail from TM) + Rename Position columns
df_final = (
    df_final
      .drop(columns=["Pos"], errors="ignore")      
      .rename(columns={"Position_x": "Position_FBRef","Position_y": "Position_TM"})            # replace with your rename mapping
)

# %%
# 1. Adjust 'unclear' positions
# --- RM -> RB if FBRef==Defender else RW
m = df_final["Position_TM"].eq("RM")
df_final.loc[m & df_final["Position_FBRef"].eq("Defender"), "Position_TM"] = "RB"
df_final.loc[m & ~df_final["Position_FBRef"].eq("Defender"), "Position_TM"] = "RW"

# --- LM -> LB if FBRef==Defender else LW
m = df_final["Position_TM"].eq("LM")
df_final.loc[m & df_final["Position_FBRef"].eq("Defender"), "Position_TM"] = "LB"
df_final.loc[m & ~df_final["Position_FBRef"].eq("Defender"), "Position_TM"] = "LW"

# --- SS -> CF if FBRef==Forward else AM
m = df_final["Position_TM"].eq("SS")
df_final.loc[m & df_final["Position_FBRef"].eq("Forward"), "Position_TM"] = "CF"
df_final.loc[m & ~df_final["Position_FBRef"].eq("Forward"), "Position_TM"] = "AM"

# --- Invalid Positions
valid_positions = ["CB","RB","LB","DM","CM","AM","RW","LW","CF"]
df_final.loc[~df_final["Position_TM"].isin(valid_positions), "Position_TM"] = "Undefined"

# 2. Apply final Position Label
position_map = {
    "CB": "Centre Back (CB)",
    "RB": "Right Back (RB)",
    "LB": "Left Back (LB)",
    "DM": "Defensive Midfielder (DM)",
    "CM": "Center Midfielder (CM)",
    "AM": "Attacking Midfielder (AM)",    
    "RW": "Rigth Winger (RW)",
    "LW": "Left Winger (LW)",
    "CF": "Center Forward (CF)"
}

df_final["Position"] = df_final["Position_TM"].map(position_map).fillna(df_final["Position_TM"])

# 3. Fallback to FBRef if missing/unmapped position
mask = df_final["Position"].isna() | (df_final["Position"] == "") | (df_final["Position"] == "Undefined")
df_final.loc[mask, "Position"] = df_final.loc[mask, "Position_FBRef"]

# %%
df_final = df_final.drop(columns=["Position_FBRef","Position_TM"], errors="ignore")

# %%
# Adjust column order
cols = [c for c in df_final.columns if c not in ["Position", "Market Value"]]
cols.insert(5, "Position")     
cols.insert(8, "Market Value") 
df_final = df_final[cols]

# %%
# Convert Market Value to numeric
def convert_market_value(val):
    if pd.isna(val):
        return None
    val = str(val).replace("€", "").strip().lower()
    if val.endswith("m"):
        return float(val.replace("m", ""))  # already in millions
    elif val.endswith("k"):
        return float(val.replace("k", "")) / 1000  # convert thousands to millions
    else:
        return None 

df_final["Market Value"] = df_final["Market Value"].apply(convert_market_value).round(1)
df_final = df_final.rename(columns={"Market Value": "Market Value (M€)"})

# %%
df_final.head(10)
# Out:
#    PlayerID            Player League             Squad  elegible  \
# 0         1     Matías Abaldo   arg1     Independiente         0
# 1         2     Lucas Abascia   arg1  Cen. Córdoba–SdE         1
# 2         3  Luciano Abecasis   arg1    Ind. Rivadavia         0
# 3         4       Ramón Ábila   arg1           Huracán         0
# 4         5   Ignacio Abraham   arg1          Banfield         1
# 5         6    Gonzalo Abrego   arg1        Godoy Cruz         1
# 6         7     Jonás Acevedo   arg1         Instituto         1
# 7         8     Juan Achetoni   arg1          Aldosivi         0
# 8         9  Guillermo Acosta   arg1      Atlé Tucumán         1
# 9        10    Lautaro Acosta   arg1             Lanús         0
#
#                  Position  Age Nation  Market Value (M€)  Matches  Starts  \
# 0                 Forward   21    URU                NaN        3       3
# 1        Centre Back (CB)   30    ARG                0.8       14      11
# 2                Defender   35    ARG                NaN        1       1
# 3                 Forward   36    ARG                NaN       10       0
# 4          Left Back (LB)   27    SYR                0.3       12      11
# 5  Center Midfielder (CM)   25    ARG                2.0       19      12
# 6        Left Winger (LW)   28    ARG                1.0       17       9
# 7                 Forward   20    ARG                NaN        1       0
# 8  Center Midfielder (CM)   37    ARG                0.2       15      11
# 9                 Forward   37    ARG                NaN        4       0
#
#    Minutes  Goals  Expected Goals  Goals Minus Expected  Goals not Penalty  \
# 0      201      0             0.2                  -0.2                  0
# 1     1063      1             0.8                   0.2                  1
# 2       90      0             0.1                  -0.1                  0
# 3      184      0             0.3                  -0.3                  0
# 4      984      0             0.5                  -0.5                  0
# 5     1100      0             0.8                  -0.8                  0
# 6      897      1             1.4                  -0.4                  1
# 7        3      0             0.0                   0.0                  0
# 8      912      0             0.4                  -0.4                  0
# 9       23      0             0.0                   0.0                  0
#
#    Penalty Goals  Penalty Efficacy  Shoots  Shoots on Target  Goals/Shoot  \
# 0              0               NaN       2                 1         0.00
# 1              0               NaN       9                 2         0.11
# 2              0               NaN       1                 1         0.00
# 3              0               NaN       3                 1         0.00
# 4              0               NaN       8                 1         0.00
# 5              0               NaN      19                 5         0.00
# 6              0               NaN      16                 5         0.06
# 7              0               NaN       0                 0          NaN
# 8              0               NaN       8                 2         0.00
# 9              0               NaN       0                 0          NaN
#
#    AvgShoot Distance  FreeKick Tacker  Assists  Crosses  Penalty Won  \
# 0               16.7                0        0        3            0
# 1               17.2                0        1        0            0
# 2               15.9                0        1        3            0
# 3               18.7                0        0        1            0
# 4               19.7                0        0       57            0
# 5               24.3                0        0       53            0
# 6               20.2                0        0       44            0
# 7                NaN                0        0        0            0
# 8               26.9                0        1        9            0
# 9                NaN                0        0        0            0
#
#    Offsides  Cmp Passes  Cmp Passes%  Prog Passes  Passing Distance  \
# 0         3          45         70.3            8               597
# 1         0         542         79.5           46             11663
# 2         0          37         71.2            3               587
# 3         2          27         60.0            5               428
# 4         1         261         59.5           36              4919
# 5         1         379         69.8           63              7502
# 6         5         244         70.1           40              4062
# 7         0           1         33.3            0                15
# 8         0         366         79.0           57              6703
# 9         0          12         92.3            1               159
#
#    Pass Prog Distance  Short Cmp  Short Cmp%  Medium Cmp  Medium Cmp%  \
# 0                 231         29        80.6          13         72.2
# 1                4182        149        86.6         305         89.7
# 2                 266         23        95.8          11         64.7
# 3                 100         16        57.1           7         77.8
# 4                2584        101        74.8         118         67.4
# 5                2637        160        80.0         150         73.5
# 6                1374        125        88.0          95         76.6
# 7                   0          1       100.0           0          0.0
# 8                2549        152        85.4         163         82.3
# 9                  19          8       100.0           4         80.0
#
#    Long Cmp  Long Cmp%  Key Passes  Goal Creating Actions  Take-Ons Succ  \
# 0         2       50.0           1                      4              1
# 1        85       53.8           2                     12              4
# 2         3       27.3           1                      4              0
# 3         2      100.0           3                      7              1
# 4        36       37.1          11                     19             10
# 5        60       56.1          22                     40             11
# 6        18       34.6           9                     34             11
# 7         0        NaN           0                      0              0
# 8        44       65.7           4                     27              3
# 9         0        NaN           2                      2              0
#
#    Take-Ons Succ%  Fouls Suffered  Carries  Carries TotDist  Prog Carries  \
# 0            12.5               3       50              226             3
# 1            57.1              11      448             2377             7
# 2             0.0               0       24              138             3
# 3            33.3               4       32              127             1
# 4            41.7              13      231             1561            27
# 5            55.0               5      301             1508            10
# 6            42.3              11      236             1319            15
# 7             NaN               0        2                9             0
# 8            60.0              10      224             1033             7
# 9             0.0               2        7               30             2
#
#    Carries PrgDist  Carries 1/3  Touches  Errors  Aerial Duels  \
# 0               82            0       96       0             6
# 1             1442            5      880       1            64
# 2               85            3       68       1             1
# 3               42            3       61       0             6
# 4              880           15      572       0            29
# 5              731            9      695       1            65
# 6              535           13      445       0            21
# 7                8            0        6       0             0
# 8              550            7      552       0            30
# 9               21            0       15       0             1
#
#    Aerial Duels Won%  Tackles  Tackles Won  Blocks  Interceptions  \
# 0               50.0        2            1       3              1
# 1               50.0       26           17      16             36
# 2              100.0        2            2       4              0
# 3               33.3        0            0       0              0
# 4               44.8       16           12      11              6
# 5               55.4       27           16      18              8
# 6               38.1       16           13       8              6
# 7                NaN        1            0       0              0
# 8               63.3       21           15       6             17
# 9                0.0        0            0       1              0
#
#    Ball Recoveries  Clearances  Own Goals  Fouls Commited  Penalty Commited  \
# 0                7           0          0               0                 0
# 1               70          93          0               6                 0
# 2                5           4          0               0                 0
# 3                3           0          0               2                 0
# 4               32          48          0              12                 0
# 5               72          26          0              11                 0
# 6               45           7          0              12                 0
# 7                0           1          0               1                 0
# 8               54          18          1              13                 0
# 9                1           0          0               0                 0
#
#    Yellow Cards  Red Cards  Goals_90m  Expected Goals_90m  \
# 0             0          0      0.000               0.090
# 1             2          0      0.085               0.068
# 2             0          0      0.000               0.100
# 3             1          0      0.000               0.147
# 4             1          0      0.000               0.046
# 5             2          0      0.000               0.065
# 6             3          0      0.100               0.140
# 7             0          0      0.000               0.000
# 8             3          0      0.000               0.039
# 9             1          0      0.000               0.000
#
#    Goals Minus Expected_90m  Goals not Penalty_90m  Penalty Goals_90m  \
# 0                    -0.090                  0.000                0.0
# 1                     0.017                  0.085                0.0
# 2                    -0.100                  0.000                0.0
# 3                    -0.147                  0.000                0.0
# 4                    -0.046                  0.000                0.0
# 5                    -0.065                  0.000                0.0
# 6                    -0.040                  0.100                0.0
# 7                     0.000                  0.000                0.0
# 8                    -0.039                  0.000                0.0
# 9                     0.000                  0.000                0.0
#
#    Shoots_90m  Shoots on Target_90m  Assists_90m  Crosses_90m  \
# 0       0.896                 0.448        0.000        1.343
# 1       0.762                 0.169        0.085        0.000
# 2       1.000                 1.000        1.000        3.000
# 3       1.467                 0.489        0.000        0.489
# 4       0.732                 0.091        0.000        5.213
# 5       1.555                 0.409        0.000        4.336
# 6       1.605                 0.502        0.000        4.415
# 7       0.000                 0.000        0.000        0.000
# 8       0.789                 0.197        0.099        0.888
# 9       0.000                 0.000        0.000        0.000
#
#    Penalty Won_90m  Offsides_90m  Cmp Passes_90m  Prog Passes_90m  \
# 0              0.0         1.343          20.149            3.582
# 1              0.0         0.000          45.889            3.895
# 2              0.0         0.000          37.000            3.000
# 3              0.0         0.978          13.207            2.446
# 4              0.0         0.091          23.872            3.293
# 5              0.0         0.082          31.009            5.155
# 6              0.0         0.502          24.482            4.013
# 7              0.0         0.000          30.000            0.000
# 8              0.0         0.000          36.118            5.625
# 9              0.0         0.000          46.957            3.913
#
#    Passing Distance_90m  Pass Prog Distance_90m  Short Cmp_90m  \
# 0               267.313                 103.433         12.985
# 1               987.460                 354.073         12.615
# 2               587.000                 266.000         23.000
# 3               209.348                  48.913          7.826
# 4               449.909                 236.341          9.238
# 5               613.800                 215.755         13.091
# 6               407.559                 137.860         12.542
# 7               450.000                   0.000         30.000
# 8               661.480                 251.546         15.000
# 9               622.174                  74.348         31.304
#
#    Medium Cmp_90m  Long Cmp_90m  Key Passes_90m  Goal Creating Actions_90m  \
# 0           5.821         0.896           0.448                      1.791
# 1          25.823         7.197           0.169                      1.016
# 2          11.000         3.000           1.000                      4.000
# 3           3.424         0.978           1.467                      3.424
# 4          10.793         3.293           1.006                      1.738
# 5          12.273         4.909           1.800                      3.273
# 6           9.532         1.806           0.903                      3.411
# 7           0.000         0.000           0.000                      0.000
# 8          16.086         4.342           0.395                      2.664
# 9          15.652         0.000           7.826                      7.826
#
#    Take-Ons Succ_90m  Fouls Suffered_90m  Carries_90m  Carries TotDist_90m  \
# 0              0.448               1.343       22.388              101.194
# 1              0.339               0.931       37.930              201.251
# 2              0.000               0.000       24.000              138.000
# 3              0.489               1.957       15.652               62.120
# 4              0.915               1.189       21.128              142.774
# 5              0.900               0.409       24.627              123.382
# 6              1.104               1.104       23.679              132.341
# 7              0.000               0.000       60.000              270.000
# 8              0.296               0.987       22.105              101.941
# 9              0.000               7.826       27.391              117.391
#
#    Prog Carries_90m  Carries PrgDist_90m  Carries 1/3_90m  Touches_90m  \
# 0             1.343               36.716            0.000       42.985
# 1             0.593              122.088            0.423       74.506
# 2             3.000               85.000            3.000       68.000
# 3             0.489               20.543            1.467       29.837
# 4             2.470               80.488            1.372       52.317
# 5             0.818               59.809            0.736       56.864
# 6             1.505               53.679            1.304       44.649
# 7             0.000              240.000            0.000      180.000
# 8             0.691               54.276            0.691       54.474
# 9             7.826               82.174            0.000       58.696
#
#    Errors_90m  Aerial Duels_90m  Tackles_90m  Tackles Won_90m  Blocks_90m  \
# 0       0.000             2.687        0.896            0.448       1.343
# 1       0.085             5.419        2.201            1.439       1.355
# 2       1.000             1.000        2.000            2.000       4.000
# 3       0.000             2.935        0.000            0.000       0.000
# 4       0.000             2.652        1.463            1.098       1.006
# 5       0.082             5.318        2.209            1.309       1.473
# 6       0.000             2.107        1.605            1.304       0.803
# 7       0.000             0.000       30.000            0.000       0.000
# 8       0.000             2.961        2.072            1.480       0.592
# 9       0.000             3.913        0.000            0.000       3.913
#
#    Interceptions_90m  Ball Recoveries_90m  Clearances_90m  Own Goals_90m  \
# 0              0.448                3.134           0.000          0.000
# 1              3.048                5.927           7.874          0.000
# 2              0.000                5.000           4.000          0.000
# 3              0.000                1.467           0.000          0.000
# 4              0.549                2.927           4.390          0.000
# 5              0.655                5.891           2.127          0.000
# 6              0.602                4.515           0.702          0.000
# 7              0.000                0.000          30.000          0.000
# 8              1.678                5.329           1.776          0.099
# 9              0.000                3.913           0.000          0.000
#
#    Fouls Commited_90m  Penalty Commited_90m  Yellow Cards_90m  Red Cards_90m  \
# 0               0.000                   0.0             0.000            0.0
# 1               0.508                   0.0             0.169            0.0
# 2               0.000                   0.0             0.000            0.0
# 3               0.978                   0.0             0.489            0.0
# 4               1.098                   0.0             0.091            0.0
# 5               0.900                   0.0             0.164            0.0
# 6               1.204                   0.0             0.301            0.0
# 7              30.000                   0.0             0.000            0.0
# 8               1.283                   0.0             0.296            0.0
# 9               0.000                   0.0             3.913            0.0
#
#    Goals_90m_scaled  Expected Goals_90m_scaled  \
# 0               NaN                        NaN
# 1             0.099                      0.089
# 2               NaN                        NaN
# 3               NaN                        NaN
# 4             0.000                      0.060
# 5             0.000                      0.085
# 6             0.116                      0.183
# 7               NaN                        NaN
# 8             0.000                      0.051
# 9               NaN                        NaN
#
#    Goals Minus Expected_90m_scaled  Goals not Penalty_90m_scaled  \
# 0                              NaN                           NaN
# 1                            0.529                         0.105
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                            0.439                         0.000
# 5                            0.412                         0.000
# 6                            0.448                         0.124
# 7                              NaN                           NaN
# 8                            0.449                         0.000
# 9                              NaN                           NaN
#
#    Penalty Goals_90m_scaled  Penalty Efficacy_scaled  Shoots_90m_scaled  \
# 0                       NaN                      NaN                NaN
# 1                       0.0                      NaN              0.176
# 2                       NaN                      NaN                NaN
# 3                       NaN                      NaN                NaN
# 4                       0.0                      NaN              0.169
# 5                       0.0                      NaN              0.360
# 6                       0.0                      NaN              0.371
# 7                       NaN                      NaN                NaN
# 8                       0.0                      NaN              0.183
# 9                       NaN                      NaN                NaN
#
#    Shoots on Target_90m_scaled  Goals/Shoot_scaled  AvgShoot Distance_scaled  \
# 0                          NaN                 NaN                       NaN
# 1                        0.090                0.22                     0.431
# 2                          NaN                 NaN                       NaN
# 3                          NaN                 NaN                       NaN
# 4                        0.048                0.00                     0.532
# 5                        0.217                0.00                     0.719
# 6                        0.267                0.12                     0.553
# 7                          NaN                 NaN                       NaN
# 8                        0.105                0.00                     0.824
# 9                          NaN                 NaN                       NaN
#
#    Assists_90m_scaled  Crosses_90m_scaled  Penalty Won_90m_scaled  \
# 0                 NaN                 NaN                     NaN
# 1               0.162               0.000                     0.0
# 2                 NaN                 NaN                     NaN
# 3                 NaN                 NaN                     NaN
# 4               0.000               0.602                     0.0
# 5               0.000               0.500                     0.0
# 6               0.000               0.510                     0.0
# 7                 NaN                 NaN                     NaN
# 8               0.189               0.102                     0.0
# 9                 NaN                 NaN                     NaN
#
#    Offsides_90m_scaled  Cmp Passes_90m_scaled  Cmp Passes%_scaled  \
# 0                  NaN                    NaN                 NaN
# 1                0.000                  0.527               0.667
# 2                  NaN                    NaN                 NaN
# 3                  NaN                    NaN                 NaN
# 4                0.063                  0.224               0.197
# 5                0.057                  0.322               0.439
# 6                0.349                  0.233               0.446
# 7                  NaN                    NaN                 NaN
# 8                0.000                  0.393               0.655
# 9                  NaN                    NaN                 NaN
#
#    Prog Passes_90m_scaled  Passing Distance_90m_scaled  \
# 0                     NaN                          NaN
# 1                   0.361                        0.650
# 2                     NaN                          NaN
# 3                     NaN                          NaN
# 4                   0.296                        0.254
# 5                   0.499                        0.375
# 6                   0.374                        0.223
# 7                     NaN                          NaN
# 8                   0.550                        0.410
# 9                     NaN                          NaN
#
#    Pass Prog Distance_90m_scaled  Short Cmp_90m_scaled  Short Cmp%_scaled  \
# 0                            NaN                   NaN                NaN
# 1                          0.675                 0.245              0.724
# 2                            NaN                   NaN                NaN
# 3                            NaN                   NaN                NaN
# 4                          0.440                 0.147              0.414
# 5                          0.399                 0.259              0.551
# 6                          0.244                 0.243              0.761
# 7                            NaN                   NaN                NaN
# 8                          0.470                 0.314              0.693
# 9                            NaN                   NaN                NaN
#
#    Medium Cmp_90m_scaled  Medium Cmp%_scaled  Long Cmp_90m_scaled  \
# 0                    NaN                 NaN                  NaN
# 1                  0.587               0.848                0.745
# 2                    NaN                 NaN                  NaN
# 3                    NaN                 NaN                  NaN
# 4                  0.218               0.372                0.341
# 5                  0.254               0.502                0.508
# 6                  0.187               0.568                0.187
# 7                    NaN                 NaN                  NaN
# 8                  0.348               0.690                0.450
# 9                    NaN                 NaN                  NaN
#
#    Long Cmp%_scaled  Key Passes_90m_scaled  Goal Creating Actions_90m_scaled  \
# 0               NaN                    NaN                               NaN
# 1             0.476                  0.053                             0.130
# 2               NaN                    NaN                               NaN
# 3               NaN                    NaN                               NaN
# 4             0.286                  0.317                             0.241
# 5             0.502                  0.567                             0.477
# 6             0.258                  0.284                             0.498
# 7               NaN                    NaN                               NaN
# 8             0.611                  0.124                             0.383
# 9               NaN                    NaN                               NaN
#
#    Take-Ons Succ_90m_scaled  Take-Ons Succ%_scaled  Fouls Suffered_90m_scaled  \
# 0                       NaN                    NaN                        NaN
# 1                     0.101                  0.571                      0.235
# 2                       NaN                    NaN                        NaN
# 3                       NaN                    NaN                        NaN
# 4                     0.274                  0.417                      0.300
# 5                     0.269                  0.550                      0.103
# 6                     0.330                  0.423                      0.278
# 7                       NaN                    NaN                        NaN
# 8                     0.089                  0.600                      0.249
# 9                       NaN                    NaN                        NaN
#
#    Carries_90m_scaled  Carries TotDist_90m_scaled  Prog Carries_90m_scaled  \
# 0                 NaN                         NaN                      NaN
# 1               0.529                       0.513                    0.091
# 2                 NaN                         NaN                      NaN
# 3                 NaN                         NaN                      NaN
# 4               0.212                       0.329                    0.380
# 5               0.278                       0.268                    0.126
# 6               0.260                       0.296                    0.231
# 7                 NaN                         NaN                      NaN
# 8               0.231                       0.200                    0.106
# 9                 NaN                         NaN                      NaN
#
#    Carries PrgDist_90m_scaled  Carries 1/3_90m_scaled  Touches_90m_scaled  \
# 0                         NaN                     NaN                 NaN
# 1                       0.605                   0.109               0.694
# 2                         NaN                     NaN                 NaN
# 3                         NaN                     NaN                 NaN
# 4                       0.377                   0.352               0.404
# 5                       0.264                   0.189               0.463
# 6                       0.230                   0.335               0.304
# 7                         NaN                     NaN                 NaN
# 8                       0.233                   0.177               0.432
# 9                         NaN                     NaN                 NaN
#
#    Errors_90m_scaled  Aerial Duels_90m_scaled  Aerial Duels Won%_scaled  \
# 0                NaN                      NaN                       NaN
# 1              0.262                    0.447                     0.585
# 2                NaN                      NaN                       NaN
# 3                NaN                      NaN                       NaN
# 4              0.000                    0.207                     0.525
# 5              0.252                    0.438                     0.649
# 6              0.000                    0.160                     0.446
# 7                NaN                      NaN                       NaN
# 8              0.000                    0.234                     0.741
# 9                NaN                      NaN                       NaN
#
#    Tackles_90m_scaled  Tackles Won_90m_scaled  Blocks_90m_scaled  \
# 0                 NaN                     NaN                NaN
# 1               0.488                   0.509              0.532
# 2                 NaN                     NaN                NaN
# 3                 NaN                     NaN                NaN
# 4               0.313                   0.388              0.395
# 5               0.490                   0.463              0.578
# 6               0.347                   0.461              0.315
# 7                 NaN                     NaN                NaN
# 8               0.457                   0.523              0.232
# 9                 NaN                     NaN                NaN
#
#    Interceptions_90m_scaled  Ball Recoveries_90m_scaled  \
# 0                       NaN                         NaN
# 1                     1.000                       0.720
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                     0.223                       0.271
# 5                     0.266                       0.715
# 6                     0.245                       0.509
# 7                       NaN                         NaN
# 8                     0.682                       0.630
# 9                       NaN                         NaN
#
#    Clearances_90m_scaled  Own Goals_90m_scaled  Fouls Commited_90m_scaled  \
# 0                    NaN                   NaN                        NaN
# 1                  0.905                 0.000                      0.102
# 2                    NaN                   NaN                        NaN
# 3                    NaN                   NaN                        NaN
# 4                  0.505                 0.000                      0.290
# 5                  0.244                 0.000                      0.227
# 6                  0.081                 0.000                      0.324
# 7                    NaN                   NaN                        NaN
# 8                  0.204                 0.697                      0.349
# 9                    NaN                   NaN                        NaN
#
#    Penalty Commited_90m_scaled  Yellow Cards_90m_scaled  Red Cards_90m_scaled  \
# 0                          NaN                      NaN                   NaN
# 1                          0.0                    0.199                   0.0
# 2                          NaN                      NaN                   NaN
# 3                          NaN                      NaN                   NaN
# 4                          0.0                    0.107                   0.0
# 5                          0.0                    0.193                   0.0
# 6                          0.0                    0.355                   0.0
# 7                          NaN                      NaN                   NaN
# 8                          0.0                    0.349                   0.0
# 9                          NaN                      NaN                   NaN
#
#    Goal Scoring  Goal Efficacy  Shooting  Passing Influence  Passing Accuracy  \
# 0           NaN            NaN       NaN                NaN               NaN
# 1         0.101          0.300     0.111              0.487             0.674
# 2           NaN            NaN       NaN                NaN               NaN
# 3           NaN            NaN       NaN                NaN               NaN
# 4         0.000          0.176     0.070              0.282             0.269
# 5         0.000          0.165     0.195              0.403             0.475
# 6         0.119          0.227     0.230              0.269             0.483
# 7           NaN            NaN       NaN                NaN               NaN
# 8         0.000          0.180     0.097              0.446             0.659
# 9           NaN            NaN       NaN                NaN               NaN
#
#    Goal Creation  Possession Influence  Progression  Dribling  \
# 0            NaN                   NaN          NaN       NaN
# 1          0.107                 0.536        0.297     0.336
# 2            NaN                   NaN          NaN       NaN
# 3            NaN                   NaN          NaN       NaN
# 4          0.143                 0.306        0.379     0.346
# 5          0.265                 0.317        0.181     0.410
# 6          0.185                 0.281        0.231     0.376
# 7            NaN                   NaN          NaN       NaN
# 8          0.189                 0.315        0.157     0.344
# 9            NaN                   NaN          NaN       NaN
#
#    Aerial Influence  Defensive Influence  Discipline and Consistency
# 0               NaN                  NaN                         NaN
# 1             0.530                0.679                       0.909
# 2               NaN                  NaN                         NaN
# 3               NaN                  NaN                         NaN
# 4             0.398                0.348                       0.940
# 5             0.565                0.467                       0.893
# 6             0.332                0.338                       0.898
# 7               NaN                  NaN                         NaN
# 8             0.538                0.463                       0.773
# 9               NaN                  NaN                         NaN

# %%
df_elegible = df_final[df_final['elegible']==1]
df_elegible['Position'].value_counts().sum
# Out:
# <bound method Series.sum of Position
# Centre Back (CB)             1112
# Center Forward (CF)           785
# Center Midfielder (CM)        739
# Right Back (RB)               520
# Defensive Midfielder (DM)     507
# Left Back (LB)                466
# Rigth Winger (RW)             438
# Attacking Midfielder (AM)     437
# Left Winger (LW)              408
# Defender                      259
# Midfielder                    199
# Forward                       170
# Name: count, dtype: int64>

# %% [markdown]
# # Save

# %% [markdown]
# **Save file** as `df_proc`:

# %%
df_final.to_parquet("dfs/df_final.parquet", index=False)
df_final.to_parquet("../assets/df_final.parquet", index=False)

# %%
df_final.to_excel("dfs/df_final.xlsx", index=False)
